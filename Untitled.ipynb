# %% [markdown]
# ### Objective: Classify a new flower as belonging to one of the 3 classes using given 4 features

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df = df.drop('Id', 1)
# 0 for rows and 1 for columns

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot(kind="scatter",x="SepalLengthCm" , y="SepalWidthCm");
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="Species", height=5)\
.map(plt.scatter,"SepalLengthCm" , "SepalWidthCm")\
.add_legend();
plt.show();

# %%
sns.distplot(df['SepalLengthCm'])
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.displot(df['SepalWidthCm'])

# %%
sns.histplot(df)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x="SepalLengthCm" , y="SepalWidthCm" , data=df,kind="reg")

# %%
sns.set_style("whitegrid");
sns.pairplot(df,hue='Species');

# %%
sns.FacetGrid(df , hue="Species" , height=5)\
    .map(sns.distplot , "PetalLengthCm")\
.add_legend();

plt.show()

# %% [markdown]
# Probability Density Function (PDF) (smooth line of the histogram)
#
# here, x-axis Petal Length and y-axis is the count ( or frequency)
#
# spread-- wide these point are spread.

# %%
# Univarianr Analysis
sns.FacetGrid(df , hue="Species" , height=5)\
    .map(sns.distplot , "PetalWidthCm")\
.add_legend();

plt.show()

# %%
sns.FacetGrid(df , hue="Species" , height=5)\
    .map(sns.distplot , "SepalLengthCm")\
.add_legend();

plt.show()

# %%
sns.FacetGrid(df , hue="Species" , height=5)\
    .map(sns.distplot , "SepalWidthCm")\
.add_legend();

plt.show()

# %% [markdown]
# ## CDF AND PDF

# %%
iris_setosa=df.loc[df["Species"]=="Iris-setosa"];
counts, bin_edges=np.histogram(iris_setosa['PetalLengthCm'],bins=10,
                             density=True)
pdf=counts/sum(counts)
print(pdf)
print(bin_edges)
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
iris_setosa
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0             5.1           3.5            1.4           0.2  Iris-setosa
# 1             4.9           3.0            1.4           0.2  Iris-setosa
# 2             4.7           3.2            1.3           0.2  Iris-setosa
# 3             4.6           3.1            1.5           0.2  Iris-setosa
# 4             5.0           3.6            1.4           0.2  Iris-setosa
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa
# 11            4.8           3.4            1.6           0.2  Iris-setosa
# ...

# %%
cdf=np.cumsum(pdf);
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show();

# %% [markdown]
# ### Mean, Median,Variance and STD-dev

# %%
iris_virginica=df.loc[df["Species"]=="Iris-virginica"];
iris_versicolor=df.loc[df["Species"]=="Iris-versicolor"];

# %%
print("Mean:")
print("iris_setosa",np.mean(iris_setosa["PetalLengthCm"]))
print("iris_versicolor",np.mean(iris_versicolor["PetalLengthCm"]))
print("iris_virginica",np.mean(iris_virginica["PetalLengthCm"]))
# Out:
# Mean:
# iris_setosa 1.464
# iris_versicolor 4.26
# iris_virginica 5.552

# %% [markdown]
# - petal length of versicolor and virginica are close
#
# - if there are outlier mean can change extremly
#
# - Mean tells central tendency
#
# - Varience - averge square distnce of each value
# - std = square root of variance -numerical representation of spread ,

# %%
print("STD :")
print("iris_setosa",np.std(iris_setosa["PetalLengthCm"]))
print("iris_versicolor",np.std(iris_versicolor["PetalLengthCm"]))
print("iris_virginica",np.std(iris_virginica["PetalLengthCm"]))
# Out:
# STD :
# iris_setosa 0.17176728442867115
# iris_versicolor 0.4651881339845204
# iris_virginica 0.5463478745268441

# %%
print("Median :")
print("iris_setosa",np.median(iris_setosa["PetalLengthCm"]))
print("iris_versicolor",np.median(iris_versicolor["PetalLengthCm"]))
print("iris_virginica",np.median(iris_virginica["PetalLengthCm"]))

# very less or no change with the outlier in the datset
# if more than 50% of the data is crupted then only the value of median get incorrect
# Out:
# Median :
# iris_setosa 1.5
# iris_versicolor 4.35
# iris_virginica 5.55

# %% [markdown]
# ### Percentile and Quantile

# %%
print("Quantile :")
print("iris_setosa",np.percentile(iris_setosa["PetalLengthCm"], np.arange(0,100,25)))
print("iris_versicolor",np.percentile(iris_versicolor["PetalLengthCm"], np.arange(0,100,25)))
print("iris_virginica",np.percentile(iris_virginica["PetalLengthCm"], np.arange(0,100,25)))
# Out:
# Quantile :
# iris_setosa [1.    1.4   1.5   1.575]
# iris_versicolor [3.   4.   4.35 4.6 ]
# iris_virginica [4.5   5.1   5.55  5.875]

# %%
print("Percentile :")
print("iris_setosa",np.percentile(iris_setosa["PetalLengthCm"],90))
print("iris_versicolor",np.percentile(iris_versicolor["PetalLengthCm"],90))
print("iris_virginica",np.percentile(iris_virginica["PetalLengthCm"],90))
# Out:
# Percentile :
# iris_setosa 1.7
# iris_versicolor 4.8
# iris_virginica 6.3100000000000005

# %%
from statsmodels import robust

# %%
#Median Absolute deviation
print("MAD :")
print("iris_setosa",robust.mad(iris_setosa["PetalLengthCm"]))
print("iris_versicolor",robust.mad(iris_versicolor["PetalLengthCm"]))
print("iris_virginica",robust.mad(iris_virginica["PetalLengthCm"]))
# Out:
# MAD :
# iris_setosa 0.14826022185056031
# iris_versicolor 0.5189107764769602
# iris_virginica 0.6671709983275211

# %%
# IQR - inter quatile range 
iqr1= np.percentile(iris_setosa["PetalLengthCm"],75)
iqr2= np.percentile(iris_setosa["PetalLengthCm"],25)
print(iqr1-iqr2)
# Out:
# 0.17500000000000027

# %%
sns.boxplot(x="Species",y="PetalLengthCm",data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.violinplot(x="Species",y="PetalLengthCm",data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>
